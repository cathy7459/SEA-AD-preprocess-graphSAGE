# %% [markdown]
# # Annotation check
# Inspect taxonomy columns in processed snRNA outputs.

# %%
from pathlib import Path
import scanpy as sc
root = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
files = list((root / 'data' / 'processed' / 'snrna_annotated').glob('*.h5ad'))
sc.read_h5ad(files[0]).obs.head() if files else 'Run scripts/05_snrna_annotate.py first.'
