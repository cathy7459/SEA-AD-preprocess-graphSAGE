# %% [markdown]
# # Spatial mapping check
# Review region-specific spatial-to-snRNA mapping outputs.

# %%
from pathlib import Path
import pandas as pd
root = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
files = list((root / 'data' / 'processed' / 'spatial_mapping').glob('*.tsv'))
pd.read_csv(files[0], sep='\t').head() if files else 'Run scripts/07_spatial_map_to_snrna.py first.'
