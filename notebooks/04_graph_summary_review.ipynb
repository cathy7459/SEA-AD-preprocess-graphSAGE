# %% [markdown]
# # Graph summary review
# Inspect local donor-region graph summaries and patient features.

# %%
from pathlib import Path
import pandas as pd
root = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
path = root / 'data' / 'processed' / 'patient_features' / 'seaad_patient_graph_summaries_v1.tsv'
pd.read_csv(path, sep='\t').head() if path.exists() else 'Run scripts/09_aggregate_patient_features.py first.'
