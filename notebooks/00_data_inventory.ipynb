# %% [markdown]
# # Data inventory
# Inspect SEA-AD manifests and downloaded files without rerunning preprocessing.

# %%
from pathlib import Path
import pandas as pd
root = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
manifest = root / 'results' / 'manifests' / 'seaad_remote_file_manifest_v1.tsv'
pd.read_csv(manifest, sep='\t').head() if manifest.exists() else 'Run scripts/01_fetch_or_manifest_data.py first.'
