# %% [markdown]
# # QC exploration
# Review saved snRNA and spatial QC tables.

# %%
from pathlib import Path
import pandas as pd
root = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
qc_dir = root / 'data' / 'interim' / 'snrna_qc'
tables = list(qc_dir.glob('*qc-metrics*.tsv'))
pd.concat([pd.read_csv(p, sep='\t') for p in tables]).head() if tables else 'Run scripts/03_snrna_qc.py first.'
